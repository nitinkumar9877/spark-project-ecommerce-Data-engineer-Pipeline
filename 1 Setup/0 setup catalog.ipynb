# %%
# %sql
CREATE CATALOG if NOT EXISTS projectEcommerce
MANAGED LOCATION 'abfss://unitycatalog-data@stdecommercedevcink001.dfs.core.windows.net/ecommerce-catalog'
COMMENT 'Ecommerce data is allocated to our catalog by using external location'

# %%
# %sql
USE CATALOG projectecommerce;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS projectecommerce.bronze;
CREATE SCHEMA IF NOT EXISTS projectecommerce.silver;
CREATE SCHEMA IF NOT EXISTS projectecommerce.gold;
